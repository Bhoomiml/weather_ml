# %%
import pandas as pd

# %%
weather = pd.read_csv("local_weather.csv", index_col="DATE")

# %%
weather
# Out:
#                 STATION                                       NAME  ACMH  \
# DATE
# 01-01-1960  USW00014739  BOSTON LOGAN INTERNATIONAL AIRPORT, MA US   NaN
# 02-01-1960  USW00014739  BOSTON LOGAN INTERNATIONAL AIRPORT, MA US   NaN
# 03-01-1960  USW00014739  BOSTON LOGAN INTERNATIONAL AIRPORT, MA US   NaN
# 04-01-1960  USW00014739  BOSTON LOGAN INTERNATIONAL AIRPORT, MA US   NaN
# 05-01-1960  USW00014739  BOSTON LOGAN INTERNATIONAL AIRPORT, MA US   NaN
# ...                 ...                                        ...   ...
# 06-03-2025  USW00014739  BOSTON LOGAN INTERNATIONAL AIRPORT, MA US   NaN
# 07-03-2025  USW00014739  BOSTON LOGAN INTERNATIONAL AIRPORT, MA US   NaN
# 08-03-2025  USW00014739  BOSTON LOGAN INTERNATIONAL AIRPORT, MA US   NaN
# 09-03-2025  USW00014739  BOSTON LOGAN INTERNATIONAL AIRPORT, MA US   NaN
# 10-03-2025  USW00014739  BOSTON LOGAN INTERNATIONAL AIRPORT, MA US   NaN
#
#             ACSH   AWND  FMTM  FRGT    PGTM  PRCP  PSUN  ...  WT11  WT13  \
# ...

# %%
weather.apply(pd.isnull).sum()/weather.shape[0]
# Out:
# STATION    0.000000
# NAME       0.000000
# ACMH       0.520810
# ACSH       0.520684
# AWND       0.368401
# FMTM       0.573978
# FRGT       0.999958
# PGTM       0.249045
# PRCP       0.000084
# PSUN       0.708664
# SNOW       0.000000
# SNWD       0.354920
# TAVG       0.704716
# TMAX       0.000000
# TMIN       0.000000
# TSUN       0.506699
# WDF1       0.849313
# WDF2       0.556424
# WDF5       0.557431
# WDFG       0.458822
# WDFM       0.672504
# WESD       0.712696
# WSF1       0.849313
# WSF2       0.556424
# WSF5       0.557431
# WSFG       0.458360
# WSFM       0.672504
# WT01       0.620470
# WT02       0.947713
# WT03       0.953299
# WT04       0.978119
# WT05       0.982781
# WT06       0.987317
# WT07       0.997396
# WT08       0.821007
# WT09       0.990551
# WT10       0.999958
# WT11       0.999202
# WT13       0.902188
# WT14       0.948007
# WT15       0.997102
# WT16       0.651590
# WT17       0.996976
# WT18       0.898072
# WT19       0.998404
# ...

# %%
# PRCP = Precipitation (mm or inches as per user preference, inches to hundredths on Daily Form pdf file)
# SNOW = Snowfall (mm or inches as per user preference, inches to tenths on Daily Form pdf file)
# SNWD = Snow depth (mm or inches as per user preference, inches on Daily Form pdf file)
# TMAX = Maximum temperature (Fahrenheit or Celsius as per user preference, Fahrenheit to tenths on
# Daily Form pdf file
# TMIN = Minimum temperature (Fahrenheit or Celsius as per user preference, Fahrenheit to tenths on
# Daily Form pdf file

core_weather = weather[["PRCP", "SNOW", "SNWD", "TMAX", "TMIN"]].copy()
core_weather.columns = ["precip", "snow", "snow_depth", "temp_max", "temp_min"]

# %%
core_weather
# Out:
#             precip  snow  snow_depth  temp_max  temp_min
# DATE
# 01-01-1960    0.00   0.0         0.0        37        24
# 02-01-1960    0.00   0.0         0.0        47        23
# 03-01-1960    0.92   0.0         0.0        57        37
# 04-01-1960    0.00   0.0         0.0        41        33
# 05-01-1960    0.00   0.0         0.0        37        27
# ...            ...   ...         ...       ...       ...
# 06-03-2025    0.52   0.0         NaN        56        36
# 07-03-2025    0.00   0.0         NaN        43        29
# 08-03-2025    0.00   0.0         NaN        41        31
# 09-03-2025    0.00   0.0         NaN        46        30
# 10-03-2025    0.00   0.0         NaN        62        33
#
# [23811 rows x 5 columns]

# %%
core_weather.apply(pd.isnull).sum()
# Out:
# precip           2
# snow             0
# snow_depth    8451
# temp_max         0
# temp_min         0
# dtype: int64

# %%
#handling in missing values

core_weather.apply(pd.isnull).sum()/core_weather.shape[0]
# Out:
# precip        0.000084
# snow          0.000000
# snow_depth    0.354920
# temp_max      0.000000
# temp_min      0.000000
# dtype: float64

# %%
core_weather["snow"].value_counts()
# Out:
# snow
# 0.0     22324
# 0.1       181
# 0.2       136
# 0.3       126
# 0.4        81
#         ...
# 7.7         1
# 8.1         1
# 22.4        1
# 7.5         1
# 11.7        1
# Name: count, Length: 128, dtype: int64

# %%
core_weather["snow_depth"].value_counts()
# Out:
# snow_depth
# 0.0     13755
# 1.0       385
# 2.0       268
# 3.0       228
# 4.0       131
# 5.0       111
# 6.0        95
# 7.0        83
# 8.0        62
# 9.0        42
# 12.0       42
# 10.0       33
# 11.0       21
# 13.0       16
# 14.0       14
# 15.0       12
# 18.0       12
# 16.0       11
# 17.0       11
# 19.0        9
# 20.0        4
# 22.0        3
# 29.0        3
# 26.0        2
# 25.0        2
# 21.0        2
# 24.0        1
# 30.0        1
# 31.0        1
# Name: count, dtype: int64

# %%
del core_weather["snow_depth"]

# %%
del core_weather["snow"]

# %%
core_weather[pd.isnull(core_weather["precip"])]
# Out:
#             precip  temp_max  temp_min
# DATE
# 23-08-2003     NaN        84        65
# 24-08-2003     NaN        76        60

# %%
core_weather["precip"].value_counts() / core_weather.shape[0]
# Out:
# precip
# 0.00    0.654487
# 0.01    0.036748
# 0.02    0.020117
# 0.03    0.016421
# 0.04    0.014363
#           ...
# 3.31    0.000042
# 4.21    0.000042
# 3.36    0.000042
# 6.11    0.000042
# 1.98    0.000042
# Name: count, Length: 273, dtype: float64

# %%
core_weather["precip"] = core_weather["precip"].fillna(0)

# %%
core_weather.apply(pd.isnull).sum()
# Out:
# precip      0
# temp_max    0
# temp_min    0
# dtype: int64

# %%
core_weather[pd.isnull(core_weather["temp_min"])]
# Out:
# Empty DataFrame
# Columns: [precip, temp_max, temp_min]
# Index: []

# %%
# Check for missing value defined in data documentation
core_weather.apply(lambda x: (x == 9999).sum())
# Out:
# precip      0
# temp_max    0
# temp_min    0
# dtype: int64

# %%
core_weather.dtypes
# Out:
# precip      float64
# temp_max      int64
# temp_min      int64
# dtype: object

# %%
core_weather.index
# Out:
# Index(['01-01-1960', '02-01-1960', '03-01-1960', '04-01-1960', '05-01-1960',
#        '06-01-1960', '07-01-1960', '08-01-1960', '09-01-1960', '10-01-1960',
#        ...
#        '01-03-2025', '02-03-2025', '03-03-2025', '04-03-2025', '05-03-2025',
#        '06-03-2025', '07-03-2025', '08-03-2025', '09-03-2025', '10-03-2025'],
#       dtype='object', name='DATE', length=23811)

# %%
core_weather.index = pd.to_datetime(core_weather.index, format="%d-%m-%Y")

# %%
core_weather.index
# Out:
# DatetimeIndex(['1960-01-01', '1960-01-02', '1960-01-03', '1960-01-04',
#                '1960-01-05', '1960-01-06', '1960-01-07', '1960-01-08',
#                '1960-01-09', '1960-01-10',
#                ...
#                '2025-03-01', '2025-03-02', '2025-03-03', '2025-03-04',
#                '2025-03-05', '2025-03-06', '2025-03-07', '2025-03-08',
#                '2025-03-09', '2025-03-10'],
#               dtype='datetime64[ns]', name='DATE', length=23811, freq=None)

# %%
core_weather.index.year
# Out:
# Index([1960, 1960, 1960, 1960, 1960, 1960, 1960, 1960, 1960, 1960,
#        ...
#        2025, 2025, 2025, 2025, 2025, 2025, 2025, 2025, 2025, 2025],
#       dtype='int32', name='DATE', length=23811)

# %%
core_weather.apply(lambda x: (x==9999).sum())
# Out:
# precip      0
# temp_max    0
# temp_min    0
# dtype: int64

# %%
core_weather[["temp_max", "temp_min"]].plot(figsize=(12, 6), linewidth=2)
plt.title("Temperature Trends Over Time", fontsize=14)
plt.xlabel("Date", fontsize=12)
plt.ylabel("Temperature (°C)", fontsize=12)
plt.legend(["Max Temp", "Min Temp"], fontsize=10)
plt.grid(True, linestyle="--", alpha=0.6)  # Add a grid for clarity
plt.show()

# %%
core_weather["precip"].plot()
# Out:
# <Axes: xlabel='DATE'>

# %%
core_weather.groupby(core_weather.index.year).apply(lambda x: x["precip"].sum()).plot()
# Out:
# <Axes: xlabel='DATE'>

# %%
#Building first model

# %%
#
core_weather["target"] = core_weather.shift(-1)["temp_max"]

# %%
core_weather
# Out:
#             precip  temp_max  temp_min  target
# DATE
# 1960-01-01    0.00        37        24    47.0
# 1960-01-02    0.00        47        23    57.0
# 1960-01-03    0.92        57        37    41.0
# 1960-01-04    0.00        41        33    37.0
# 1960-01-05    0.00        37        27    36.0
# ...            ...       ...       ...     ...
# 2025-03-06    0.52        56        36    43.0
# 2025-03-07    0.00        43        29    41.0
# 2025-03-08    0.00        41        31    46.0
# 2025-03-09    0.00        46        30    62.0
# 2025-03-10    0.00        62        33     NaN
#
# [23811 rows x 4 columns]

# %%
core_weather = core_weather.iloc[:-1,:].copy()

# %%
core_weather
# Out:
#             precip  temp_max  temp_min  target
# DATE
# 1960-01-01    0.00        37        24    47.0
# 1960-01-02    0.00        47        23    57.0
# 1960-01-03    0.92        57        37    41.0
# 1960-01-04    0.00        41        33    37.0
# 1960-01-05    0.00        37        27    36.0
# ...            ...       ...       ...     ...
# 2025-03-05    0.32        56        42    56.0
# 2025-03-06    0.52        56        36    43.0
# 2025-03-07    0.00        43        29    41.0
# 2025-03-08    0.00        41        31    46.0
# 2025-03-09    0.00        46        30    62.0
#
# [23810 rows x 4 columns]

# %%
from sklearn.linear_model import Ridge

reg = Ridge(alpha=.1)

# %%
predictors = ["precip", "temp_max", "temp_min"]

# %%
train = core_weather.loc[:"2022-12-31"]
test = core_weather.loc["2023-01-01":]

# %%
train
# Out:
#             precip  temp_max  temp_min  target
# DATE
# 1960-01-01    0.00        37        24    47.0
# 1960-01-02    0.00        47        23    57.0
# 1960-01-03    0.92        57        37    41.0
# 1960-01-04    0.00        41        33    37.0
# 1960-01-05    0.00        37        27    36.0
# ...            ...       ...       ...     ...
# 2022-12-27    0.00        36        28    43.0
# 2022-12-28    0.00        43        24    54.0
# 2022-12-29    0.00        54        32    63.0
# 2022-12-30    0.00        63        39    54.0
# 2022-12-31    0.35        54        44    55.0
#
# [23011 rows x 4 columns]

# %%
test
# Out:
#             precip  temp_max  temp_min  target
# DATE
# 2023-01-01    0.04        55        43    52.0
# 2023-01-02    0.00        52        36    45.0
# 2023-01-03    0.48        45        34    45.0
# 2023-01-04    0.32        45        40    45.0
# 2023-01-05    0.09        45        35    36.0
# ...            ...       ...       ...     ...
# 2025-03-05    0.32        56        42    56.0
# 2025-03-06    0.52        56        36    43.0
# 2025-03-07    0.00        43        29    41.0
# 2025-03-08    0.00        41        31    46.0
# 2025-03-09    0.00        46        30    62.0
#
# [799 rows x 4 columns]

# %%
reg.fit(train[predictors], train["target"])
# Out:
# Ridge(alpha=0.1)

# %%
predictions = reg.predict(test[predictors])

# %%
from sklearn.metrics import mean_squared_error

mean_squared_error(test["target"], predictions)
# Out:
# 56.3361849869503

# %%
combined = pd.concat([test["target"], pd.Series(predictions, index=test.index)], axis=1)
combined.columns = ["actual", "predictions"]

# %%
combined
# Out:
#             actual  predictions
# DATE
# 2023-01-01    52.0    57.019136
# 2023-01-02    45.0    52.160141
# 2023-01-03    45.0    46.647610
# 2023-01-04    45.0    50.238524
# 2023-01-05    36.0    48.292941
# ...            ...          ...
# 2025-03-05    56.0    56.131631
# 2025-03-06    43.0    52.425467
# 2025-03-07    41.0    44.540551
# 2025-03-08    46.0    44.702075
# 2025-03-09    62.0    46.384877
#
# [799 rows x 2 columns]

# %%
combined.plot()
# Out:
# <Axes: xlabel='DATE'>

# %%
reg.coef_
# Out:
# array([-2.8812262 ,  0.44089097,  0.52165303])

# %%
#Precipitation (precip)	-2.88	For every 1 unit increase in precipitation, the target decreases by 2.88 units, assuming temp_max and temp_min remain constant.
#Max Temperature (temp_max)	0.44	For every 1°C (or unit) increase in temp_max, the target increases by 0.44 units.
#Min Temperature (temp_min)	0.52	For every 1°C (or unit) increase in temp_min, the target increases by 0.52 units.

# %%
#Creating the function to make predictions

# %%
core_weather["month_max"] = core_weather["temp_max"].rolling(30).mean()

core_weather["month_day_max"] = core_weather["month_max"] / core_weather["temp_max"]

core_weather["max_min"] = core_weather["temp_max"] / core_weather["temp_min"]

# %%
core_weather = core_weather.iloc[30:,:].copy()

# %%
def create_predictions(predictors, core_weather, reg):
    train = core_weather.loc[:"2020-12-31"]
    test = core_weather.loc["2021-01-01":]

    reg.fit(train[predictors], train["target"])
    predictions = reg.predict(test[predictors])

    error = mean_squared_error(test["target"], predictions)
    
    combined = pd.concat([test["target"], pd.Series(predictions, index=test.index)], axis=1)
    combined.columns = ["actual", "predictions"]
    return error, combined

# %%
predictors = ["precip", "temp_max", "temp_min", "month_day_max", "max_min"]

# %%
combined.plot()
# Out:
# <Axes: xlabel='DATE'>

# %%
combined["diff"] = (combined["actual"] - combined["predictions"]).abs()

# %%
combined.sort_values("diff", ascending=False).head(10)
# Out:
#             actual  predictions       diff
# DATE
# 2023-02-04    51.0    13.173809  37.826191
# 2024-11-04    75.0    50.756706  24.243294
# 2024-02-25    56.0    34.231934  21.768066
# 2024-05-05    77.0    55.999358  21.000642
# 2024-05-20    84.0    64.033717  19.966283
# 2025-03-03    51.0    31.263540  19.736460
# 2023-04-10    76.0    56.569051  19.430949
# 2023-06-02    57.0    75.716421  18.716421
# 2023-04-12    88.0    69.324409  18.675591
# 2024-11-01    56.0    73.975605  17.975605
